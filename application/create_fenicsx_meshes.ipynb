# %%
from pathlib import Path

from cardiac_electrophysiology.utils import mesh_processing

# %%
patient_ids = ("01", "02", "03", "04", "05", "06", "07")

for patient_id in patient_ids:
    input_path = Path(f"../data/patient_{patient_id}/mesh_with_fibers_tags.vtu")
    mesh_processing.convert_vtu_to_xdmf_mesh(input_path)
